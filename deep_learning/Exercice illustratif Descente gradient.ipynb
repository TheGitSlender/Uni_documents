# %% [markdown]
# On simule d’un jeu de données synthétique comme suit :
#
# - Les entrées 𝑋 sont des valeurs générées aléatoirement.
# - Les sorties 𝑦 sont définies par une relation linéaire bruitée : y=3x+4
#
# Votre tâche est d’estimer les paramètres 𝑤 (pente) et 𝑏(ordonnée à l’origine) d’un modèle de régression linéaire, tel que : y_pred = w⋅x + b
#     Fonction de perte: MSE
#     learning_rate = 0.01
#     num_iterations (Epochs) = 1000
#
# Pour ce faire:
# 1. Donnez l'expression mathématique de la descente de gradient pour 𝑤 et 𝑏
# 2. Implémentez la fonction mse(y, y_pred) pour le calcul de la perte globale
# 3. Implémentez la fonction update_parameters(num_iterations) qui fait ce qui suit pour chaque itération:
#         - Calcul des gradients
#         - Mise à jour des paramètres
#         - Affichage du coût toutes les 100 itérations
# 4. Afficher les valeurs finales de 𝑤 et 𝑏
# 5. Afficher le graphique qui montre les données réelles et la ligne de régression obtenue après optimisation (y_pred = w⋅x + b)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Générer des données synthétiques
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Initialiser les paramètres
w = np.random.randn(1, 1)
b = np.random.randn(1)

# Fonction de coût (erreur quadratique moyenne)
def mse(y_true, y_pred):
    ...
    return ...

# Descente de gradient
def gradient_descent(X, y, w, b, learning_rate, num_iterations):
    n = len(y)
    for i in range(num_iterations):
        y_pred = ...
        dw = ...
        db = ...
        w = ...
        b = ...
        
        # Affichage du coût, w et b toutes les 100 itérations
        ...
    return w, b

# Entraîner le modèle
w_final, b_final = gradient_descent(X, y, w, b, learning_rate=0.01, num_iterations=1000)

# Faire des prédictions
y_pred = np.dot(X, w_final) + b_final

# Visualiser les résultats
plt.scatter(..., ..., label='Données')
plt.plot(..., ..., color='red', label='Régression Linéaire')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
